# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# C:/Windows/Fonts/H2GSRB.TTF
import matplotlib as mp
import matplotlib.font_manager as fm
import os
# 한글폰트 - matplot lib 한글을 지원안하므로 자신의 컴에 있는 한글 폰트는 셋팅
location = 'C:/Windows/Fonts/H2GSRB.TTF'
font_name = fm.FontProperties(fname=location).get_name()
mp.rc('font',family=font_name)

# %%
# 주피터 노트북 실행경로
os.getcwd()
# Out:
# 'D:\\leeky_ai'

# %%
# 파일 읽기 - 데이터 수집
# seoul_df = pd.read_csv('seoul.csv',encoding='cp949')
seoul_df = pd.read_csv('seoul.csv')

# %%
pd.options.display.max_columns = None

# %%
seoul_df.head()
# Out:
#      상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0  23324279       제중건강원  NaN         D       소매       D10    건강/미용식품
# 1  24525909       민속악기사  NaN         D       소매       D04  취미/오락관련소매
# 2  24715368       태평양진주  NaN         D       소매       D26   시계/귀금속소매
# 3  15554136  김선희꼼꼼국어교습소  NaN         R    학문/교육       R01  학원-보습교습입시
# 4  17174175         비지트  NaN         Q       음식       Q01         한식
#
#   상권업종소분류코드   상권업종소분류명 표준산업분류코드       표준산업분류명  시도코드    시도명  시군구코드  시군구명  \
# 0    D10A07        건강원   G47216    건강보조식품 소매업    11  서울특별시  11560  영등포구
# 1    D04A09       악기판매   G47593        악기 소매업    11  서울특별시  11200   성동구
# 2    D26A01     시계/귀금속   G47830  시계 및 귀금속 소매업    11  서울특별시  11110   종로구
# 3    R01A01      학원-입시   P85501      일반 교과 학원    11  서울특별시  11710   송파구
# 4    Q01A01  한식/백반/한정식   I56111       한식 음식점업    11  서울특별시  11650   서초구
#
#         행정동코드         행정동명       법정동코드    법정동명                 지번코드  대지구분코드  \
# 0  1156053500         영등포동  1156010600  영등포동5가  1156010600100410001       1
# 1  1120079000          용답동  1120012200     용답동  1120012200101420011       1
# 2  1111061500  종로1.2.3.4가동  1111015200     봉익동  1111015200100430001       1
# 3  1171056100         방이1동  1171011100     방이동  1171011100101970003       1
# 4  1165062100         방배4동  1165010100     방배동  1165010100108540018       1
#
#   대지구분명  지번본번지  지번부번지                    지번주소         도로명코드  \
# 0    대지     41    1.0  서울특별시 영등포구 영등포동5가 41-1  115604154799
# 1    대지    142   11.0    서울특별시 성동구 용답동 142-11  112004109480
# 2    대지     43    1.0      서울특별시 종로구 봉익동 43-1  111104100163
# 3    대지    197    3.0     서울특별시 송파구 방이동 197-3  117104169448
# 4    대지    854   18.0    서울특별시 서초구 방배동 854-18  116504163117
#
#                   도로명  건물본번지  건물부번지                     건물관리번호     건물명  \
# 0   서울특별시 영등포구 영중로14길     11   17.0  1156010600100410002034626     NaN
# 1      서울특별시 성동구 용답5길      2    NaN  1120012200101420011000227     NaN
# 2      서울특별시 종로구 서순라길     17   10.0  1111015200100440000000001  금사랑투빌딩
# 3  서울특별시 송파구 위례성대로12길     31    NaN  1171011100101970003017195     NaN
# 4    서울특별시 서초구 동광로18길     82    NaN  1165010100108540018009586   상랑의빌딩
#
#                      도로명주소   구우편번호   신우편번호  동정보  층정보  호정보          경도  \
# 0  서울특별시 영등포구 영중로14길 11-17  150035  7250.0  NaN    1  NaN  126.907168
# 1         서울특별시 성동구 용답5길 2  133849  4803.0  NaN  NaN  NaN  127.049018
# 2     서울특별시 종로구 서순라길 17-10  110390  3138.0  NaN  NaN  NaN  126.993530
# 3    서울특별시 송파구 위례성대로12길 31  138834  5640.0  NaN    2  NaN  127.121520
# 4      서울특별시 서초구 동광로18길 82  137837  6572.0  NaN    1  NaN  126.991394
#
#           위도
# 0  37.520613
# 1  37.566857
# 2  37.571848
# 3  37.510967
# 4  37.488375

# %%
seoul_df.shape
# Out:
# (346229, 39)

# %%
seoul_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346229 entries, 0 to 346228
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     346229 non-null  int64
#  1   상호명        346229 non-null  object
#  2   지점명        59038 non-null   object
#  3   상권업종대분류코드  346229 non-null  object
#  4   상권업종대분류명   346229 non-null  object
#  5   상권업종중분류코드  346229 non-null  object
#  6   상권업종중분류명   346229 non-null  object
#  7   상권업종소분류코드  346229 non-null  object
#  8   상권업종소분류명   346229 non-null  object
#  9   표준산업분류코드   323688 non-null  object
#  10  표준산업분류명    323688 non-null  object
#  11  시도코드       346229 non-null  int64
#  12  시도명        346229 non-null  object
#  13  시군구코드      346229 non-null  int64
#  14  시군구명       346229 non-null  object
#  15  행정동코드      346229 non-null  int64
#  16  행정동명       346229 non-null  object
#  17  법정동코드      346229 non-null  int64
#  18  법정동명       346229 non-null  object
#  19  지번코드       346229 non-null  int64
#  20  대지구분코드     346229 non-null  int64
#  21  대지구분명      346229 non-null  object
#  22  지번본번지      346229 non-null  int64
#  23  지번부번지      274757 non-null  float64
#  24  지번주소       346229 non-null  object
#  25  도로명코드      346229 non-null  int64
#  26  도로명        346229 non-null  object
#  27  건물본번지      346229 non-null  int64
#  28  건물부번지      45666 non-null   float64
#  29  건물관리번호     346229 non-null  object
#  30  건물명        170571 non-null  object
#  31  도로명주소      346229 non-null  object
#  32  구우편번호      346229 non-null  int64
#  33  신우편번호      346193 non-null  float64
#  34  동정보        37701 non-null   object
#  35  층정보        210702 non-null  object
#  36  호정보        0 non-null       float64
#  37  경도         346229 non-null  float64
#  38  위도         346229 non-null  float64
# dtypes: float64(6), int64(11), object(22)
# memory usage: 103.0+ MB

# %%
# 결측치 확인
# 2. 시각화를 통해 확인
# 1.수치형 데이터를 확인 - 갯수, 평균

# %%
# 1. 
seoul_df.isna().mean()
# Out:
# 상가업소번호       0.000000
# 상호명          0.000000
# 지점명          0.829483
# 상권업종대분류코드    0.000000
# 상권업종대분류명     0.000000
# 상권업종중분류코드    0.000000
# 상권업종중분류명     0.000000
# 상권업종소분류코드    0.000000
# 상권업종소분류명     0.000000
# 표준산업분류코드     0.065104
# 표준산업분류명      0.065104
# 시도코드         0.000000
# 시도명          0.000000
# 시군구코드        0.000000
# 시군구명         0.000000
# 행정동코드        0.000000
# 행정동명         0.000000
# 법정동코드        0.000000
# 법정동명         0.000000
# 지번코드         0.000000
# 대지구분코드       0.000000
# 대지구분명        0.000000
# 지번본번지        0.000000
# 지번부번지        0.206430
# 지번주소         0.000000
# 도로명코드        0.000000
# 도로명          0.000000
# 건물본번지        0.000000
# 건물부번지        0.868105
# 건물관리번호       0.000000
# 건물명          0.507346
# 도로명주소        0.000000
# 구우편번호        0.000000
# 신우편번호        0.000104
# 동정보          0.891110
# 층정보          0.391437
# 호정보          1.000000
# 경도           0.000000
# 위도           0.000000
# dtype: float64

# %%
seoul_df.isna().mean().plot.barh(figsize=(10,7))
# Out:
# <AxesSubplot:>

# %%
# 필요한 컬럼 
# 상호명, 상권분류.. 시도명, 시군구, 행정동, 법정동, 도로명주소, 위도 , 경도
# 원본에서 새로운 데이터를 추출해서 새로운 DataFrame에 저장
seoul_df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
new_cols = ['상호명','시도명','시군구명','행정동명','법정동명','도로명주소','경도','위도'] +  [i for i in seoul_df.columns if '상권' in i  ] 
print(new_cols)
# Out:
# ['상호명', '시도명', '시군구명', '행정동명', '법정동명', '도로명주소', '경도', '위도', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드', '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명']

# %%
new_df =  seoul_df.loc[:,new_cols]
new_df.head()
# Out:
#           상호명    시도명  시군구명         행정동명    법정동명                    도로명주소  \
# 0       제중건강원  서울특별시  영등포구         영등포동  영등포동5가  서울특별시 영등포구 영중로14길 11-17
# 1       민속악기사  서울특별시   성동구          용답동     용답동         서울특별시 성동구 용답5길 2
# 2       태평양진주  서울특별시   종로구  종로1.2.3.4가동     봉익동     서울특별시 종로구 서순라길 17-10
# 3  김선희꼼꼼국어교습소  서울특별시   송파구         방이1동     방이동    서울특별시 송파구 위례성대로12길 31
# 4         비지트  서울특별시   서초구         방배4동     방배동      서울특별시 서초구 동광로18길 82
#
#            경도         위도 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명 상권업종소분류코드  \
# 0  126.907168  37.520613         D       소매       D10    건강/미용식품    D10A07
# 1  127.049018  37.566857         D       소매       D04  취미/오락관련소매    D04A09
# 2  126.993530  37.571848         D       소매       D26   시계/귀금속소매    D26A01
# 3  127.121520  37.510967         R    학문/교육       R01  학원-보습교습입시    R01A01
# 4  126.991394  37.488375         Q       음식       Q01         한식    Q01A01
#
#     상권업종소분류명
# 0        건강원
# 1       악기판매
# 2     시계/귀금속
# 3      학원-입시
# 4  한식/백반/한정식

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346229 entries, 0 to 346228
# Data columns (total 14 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상호명        346229 non-null  object
#  1   시도명        346229 non-null  object
#  2   시군구명       346229 non-null  object
#  3   행정동명       346229 non-null  object
#  4   법정동명       346229 non-null  object
#  5   도로명주소      346229 non-null  object
#  6   경도         346229 non-null  float64
#  7   위도         346229 non-null  float64
#  8   상권업종대분류코드  346229 non-null  object
#  9   상권업종대분류명   346229 non-null  object
#  10  상권업종중분류코드  346229 non-null  object
#  11  상권업종중분류명   346229 non-null  object
#  12  상권업종소분류코드  346229 non-null  object
#  13  상권업종소분류명   346229 non-null  object
# dtypes: float64(2), object(12)
# memory usage: 37.0+ MB

# %%
# 시군구의 갯수
new_df['시군구명'].unique()
# Out:
# array(['영등포구', '성동구', '종로구', '송파구', '서초구', '동작구', '강남구', '마포구', '중랑구',
#        '은평구', '성북구', '강동구', '양천구', '서대문구', '중구', '광진구', '용산구', '관악구',
#        '강서구', '노원구', '강북구', '구로구', '금천구', '도봉구', '동대문구'], dtype=object)

# %%
new_df['시군구명'].value_counts()
# Out:
# 강남구     33454
# 송파구     21050
# 서초구     20069
# 강서구     17182
# 마포구     16740
# 중구      16599
# 영등포구    14987
# 종로구     14258
# 강동구     14004
# 광진구     13529
# 구로구     13008
# 관악구     12606
# 동대문구    12550
# 은평구     12094
# 양천구     11960
# 노원구     11904
# 성북구     11872
# 중랑구     11106
# 용산구     11022
# 성동구     10672
# 금천구      9715
# 동작구      9573
# 서대문구     9444
# 강북구      8877
# 도봉구      7954
# Name: 시군구명, dtype: int64

# %%
# 파일저장
new_df.to_csv('seoul_modify_store.csv',index=False)

# %%
df = pd.read_csv('seoul_modify_store.csv')
df.head()
# Out:
#           상호명    시도명  시군구명         행정동명    법정동명                    도로명주소  \
# 0       제중건강원  서울특별시  영등포구         영등포동  영등포동5가  서울특별시 영등포구 영중로14길 11-17
# 1       민속악기사  서울특별시   성동구          용답동     용답동         서울특별시 성동구 용답5길 2
# 2       태평양진주  서울특별시   종로구  종로1.2.3.4가동     봉익동     서울특별시 종로구 서순라길 17-10
# 3  김선희꼼꼼국어교습소  서울특별시   송파구         방이1동     방이동    서울특별시 송파구 위례성대로12길 31
# 4         비지트  서울특별시   서초구         방배4동     방배동      서울특별시 서초구 동광로18길 82
#
#            경도         위도 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명 상권업종소분류코드  \
# 0  126.907168  37.520613         D       소매       D10    건강/미용식품    D10A07
# 1  127.049018  37.566857         D       소매       D04  취미/오락관련소매    D04A09
# 2  126.993530  37.571848         D       소매       D26   시계/귀금속소매    D26A01
# 3  127.121520  37.510967         R    학문/교육       R01  학원-보습교습입시    R01A01
# 4  126.991394  37.488375         Q       음식       Q01         한식    Q01A01
#
#     상권업종소분류명
# 0        건강원
# 1       악기판매
# 2     시계/귀금속
# 3      학원-입시
# 4  한식/백반/한정식

# %%
df['상권업종중분류명'].unique()
# Out:
# array(['건강/미용식품', '취미/오락관련소매', '시계/귀금속소매', '학원-보습교습입시', '한식', '유흥주점',
#        '학원-창업취업취미', '자동차/자동차용품', '부동산중개', '사진/광학/정밀기기소매', '도서관/독서실',
#        '커피점/카페', '대중목욕탕/휴게', '주유소/충전소', '패스트푸드', '닭/오리요리', '자동차/이륜차',
#        '선물/팬시/기념품', '이/미용/건강', '사무/문구/컴퓨터', '중식', 'PC/오락/당구/볼링등',
#        '음/식료품소매', '종합소매점', '세탁/가사서비스', '기타서비스업', '의복의류', '가방/신발/액세서리',
#        '양식', '제과제빵떡케익', '무도/유흥/가무', '가정/주방/인테리어', '운동/경기용품소매', '개인서비스',
#        '학원-예능취미체육', '학원기타', '가전제품소매', '유아교육', '물품기기대여', '학문교육기타', '기타판매업',
#        '사진', '분식', '화장품소매', '애견/애완/동물', '학원-음악미술무용', '대행업',
#        '철물/난방/건설자재소매', '별식/퓨전요리', '주택수리', '연극/영화/극장', '모텔/여관/여인숙',
#        '호텔/콘도', '의약/의료품소매', '실외운동시설', '학원-어학', '기타음식업', '광고/인쇄',
#        '예식/의례/관혼상제', '실내운동시설', '일식/수산물', '책/서적/도서', '가구소매', '운송/배달/택배',
#        '요가/단전/마사지', '개인/가정용품수리', '인력/고용/용역알선', '평가/개발/관리', '법무세무회계',
#        '운영관리시설', '부페', '중고품소매/교환', '장례/묘지', '유아용품', '분양', '예술품/골동품/수석/분재',
#        '페인트/유리제품소매', '행사/이벤트', '스포츠/운동', '음식배달서비스', '놀이/여가/취미', '종교용품판매',
#        '민박/하숙', '경마/경륜/성인오락', '학원-자격/국가고시', '학원-컴퓨터', '캠프/별장/펜션',
#        '부동산관련서비스', '유스호스텔'], dtype=object)

# %%
# 상권업종중분류 중에서 패스트푸드에 해당하는 데이터 추출

# %%
# 리스트 컴프리핸선
# 판다스  - groupby ,merge, contains, isin  시각화 - seaborn(matplot wrap class)
# folium

# %%
from random import sample

# %%
list1 = sample(range(100),10)

# %%
list1
# Out:
# [17, 34, 29, 50, 74, 41, 59, 45, 76, 40]

# %%
for i in list1:
    print(i)
# Out:
# 17
# 34
# 29
# 50
# 74
# 41
# 59
# 45
# 76
# 40

# %%
[i**2 for i in list1]
# Out:
# [289, 1156, 841, 2500, 5476, 1681, 3481, 2025, 5776, 1600]

# %%
[i for i in list1 if i > 50]
# Out:
# [74, 59, 76]

# %%
['업종명'] +[i for i in seoul_df.columns if '상권' in i]
# Out:
# ['업종명',
#  '상권업종대분류코드',
#  '상권업종대분류명',
#  '상권업종중분류코드',
#  '상권업종중분류명',
#  '상권업종소분류코드',
#  '상권업종소분류명']

# %%
list1 = ['상권업종대분류코드', '상권업종대분류명']
list2 = ['홍길동']

# %%
list1+list2
# Out:
# ['상권업종대분류코드', '상권업종대분류명', '홍길동']

# %%
# DataFrame -> 엑셀형태로

# %%
data = {
    'id' : sample(range(100),10),
    'data': sample(range(100),10),
}
data
# Out:
# {'id': [16, 75, 44, 82, 46, 43, 1, 13, 38, 52],
#  'data': [61, 78, 20, 88, 36, 83, 40, 1, 31, 81]}

# %%
tm_df = pd.DataFrame(data=data)

# %%
tm_df.sum(axis=1)
# Out:
# 0     77
# 1    153
# 2     64
# 3    170
# 4     82
# 5    126
# 6     41
# 7     14
# 8     69
# 9    133
# dtype: int64

# %%
tm_df
# Out:
#    id  data
# 0  16    61
# 1  75    78
# 2  44    20
# 3  82    88
# 4  46    36
# 5  43    83
# 6   1    40
# 7  13     1
# 8  38    31
# 9  52    81

# %%
tm_df.loc[4:5,'data']
# Out:
# 4    36
# 5    83
# Name: data, dtype: int64

# %%
list1 = [11,12,13]
list1[0]
# Out:
# 11

# %%
list1 = sample(range(100),10)
list1
# Out:
# [21, 56, 9, 46, 77, 27, 82, 54, 72, 99]

# %%
list1[-3:]
# Out:
# [54, 72, 99]

# %%
list1[0:5:2]
# Out:
# [21, 9, 77]

# %%
list1[5:0:-1]
# Out:
# [27, 77, 46, 9, 56]

# %%
list1[::1]
# Out:
# [21, 56, 9, 46, 77, 27, 82, 54, 72, 99]

# %%
list1[::-1]
# Out:
# [21, 56, 9, 46, 77, 27, 82, 54, 72, 99]

# %%
# 정렬.. 오름차순....[::-1]

# %%
df = pd.read_csv('seoul_modify_store.csv')
df['상권업종중분류명'].unique()
# Out:
# array(['건강/미용식품', '취미/오락관련소매', '시계/귀금속소매', '학원-보습교습입시', '한식', '유흥주점',
#        '학원-창업취업취미', '자동차/자동차용품', '부동산중개', '사진/광학/정밀기기소매', '도서관/독서실',
#        '커피점/카페', '대중목욕탕/휴게', '주유소/충전소', '패스트푸드', '닭/오리요리', '자동차/이륜차',
#        '선물/팬시/기념품', '이/미용/건강', '사무/문구/컴퓨터', '중식', 'PC/오락/당구/볼링등',
#        '음/식료품소매', '종합소매점', '세탁/가사서비스', '기타서비스업', '의복의류', '가방/신발/액세서리',
#        '양식', '제과제빵떡케익', '무도/유흥/가무', '가정/주방/인테리어', '운동/경기용품소매', '개인서비스',
#        '학원-예능취미체육', '학원기타', '가전제품소매', '유아교육', '물품기기대여', '학문교육기타', '기타판매업',
#        '사진', '분식', '화장품소매', '애견/애완/동물', '학원-음악미술무용', '대행업',
#        '철물/난방/건설자재소매', '별식/퓨전요리', '주택수리', '연극/영화/극장', '모텔/여관/여인숙',
#        '호텔/콘도', '의약/의료품소매', '실외운동시설', '학원-어학', '기타음식업', '광고/인쇄',
#        '예식/의례/관혼상제', '실내운동시설', '일식/수산물', '책/서적/도서', '가구소매', '운송/배달/택배',
#        '요가/단전/마사지', '개인/가정용품수리', '인력/고용/용역알선', '평가/개발/관리', '법무세무회계',
#        '운영관리시설', '부페', '중고품소매/교환', '장례/묘지', '유아용품', '분양', '예술품/골동품/수석/분재',
#        '페인트/유리제품소매', '행사/이벤트', '스포츠/운동', '음식배달서비스', '놀이/여가/취미', '종교용품판매',
#        '민박/하숙', '경마/경륜/성인오락', '학원-자격/국가고시', '학원-컴퓨터', '캠프/별장/펜션',
#        '부동산관련서비스', '유스호스텔'], dtype=object)

# %%
temp = df['상권업종중분류명'].str.lower()

# %%
temp.str.extract('(패스트푸드|페스트푸드|fastfood)')[0].value_counts()
# Out:
# 패스트푸드    5662
# Name: 0, dtype: int64

# %%
len(temp)
# Out:
# 346229

# %%
fastfood_df = df[df['상권업종중분류명'] == '패스트푸드'].copy()

# %%
fastfood_df.head()
# Out:
#               상호명    시도명  시군구명  행정동명   법정동명                도로명주소          경도  \
# 23          이삭토스트  서울특별시   양천구   목5동     목동   서울특별시 양천구 목동동로 379  126.878696
# 139          본도시락  서울특별시   성북구   안암동  안암동5가     서울특별시 성북구 안암로 63  127.028589
# 200        메가박스상봉  서울특별시   중랑구  상봉2동    상봉동   서울특별시 중랑구 망우로30길 3  127.074729
# 268  던킨도너츠동대문홈플러스  서울특별시  동대문구   용신동    용두동  서울특별시 동대문구 천호대로 133  127.038754
# 594     배스킨라빈스공릉점  서울특별시   노원구  공릉2동    공릉동    서울특별시 노원구 공릉로 198  127.078586
#
#             위도 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드 상권업종소분류명
# 23   37.535600         Q       음식       Q07    패스트푸드    Q07A10    토스트전문
# 139  37.582278         Q       음식       Q07    패스트푸드    Q07A02   도시락전문점
# 200  37.593074         Q       음식       Q07    패스트푸드    Q07A04    패스트푸드
# 268  37.574540         Q       음식       Q07    패스트푸드    Q07A06    도너츠전문
# 594  37.627425         Q       음식       Q07    패스트푸드    Q07A07  아이스크림판매

# %%
fastfood_df['상권업종소분류명'].unique()
# Out:
# array(['토스트전문', '도시락전문점', '패스트푸드', '도너츠전문', '아이스크림판매', '피자전문', '샌드위치전문점',
#        '핫도그', '생과자점', '유산균아이스크림전문'], dtype=object)

# %%
food_df =  fastfood_df[fastfood_df['상권업종소분류명']=='패스트푸드']
food_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1406 entries, 200 to 345299
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   상호명        1406 non-null   object
#  1   시도명        1406 non-null   object
#  2   시군구명       1406 non-null   object
#  3   행정동명       1406 non-null   object
#  4   법정동명       1406 non-null   object
#  5   도로명주소      1406 non-null   object
#  6   경도         1406 non-null   float64
#  7   위도         1406 non-null   float64
#  8   상권업종대분류코드  1406 non-null   object
#  9   상권업종대분류명   1406 non-null   object
#  10  상권업종중분류코드  1406 non-null   object
#  11  상권업종중분류명   1406 non-null   object
#  12  상권업종소분류코드  1406 non-null   object
#  13  상권업종소분류명   1406 non-null   object
# dtypes: float64(2), object(12)
# memory usage: 164.8+ KB

# %%
food_df.head()
# Out:
#              상호명    시도명 시군구명  행정동명 법정동명                 도로명주소          경도  \
# 200       메가박스상봉  서울특별시  중랑구  상봉2동  상봉동    서울특별시 중랑구 망우로30길 3  127.074729
# 647      잠원야외수영장  서울특별시  서초구   잠원동  잠원동  서울특별시 서초구 잠원로 145-57  127.012260
# 722       좀비수제버거  서울특별시  마포구   염리동  염리동     서울특별시 마포구 숭문길 210  126.946630
# 2999   화이브앤투버거저니  서울특별시  강남구  논현2동  논현동  서울특별시 강남구 언주로115길 18  127.035149
# 3171  롯데리아올림픽공원점  서울특별시  송파구   오륜동  방이동    서울특별시 송파구 올림픽로 424  127.115777
#
#              위도 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드 상권업종소분류명
# 200   37.593074         Q       음식       Q07    패스트푸드    Q07A04    패스트푸드
# 647   37.520745         Q       음식       Q07    패스트푸드    Q07A04    패스트푸드
# 722   37.555761         Q       음식       Q07    패스트푸드    Q07A04    패스트푸드
# 2999  37.509951         Q       음식       Q07    패스트푸드    Q07A04    패스트푸드
# 3171  37.520349         Q       음식       Q07    패스트푸드    Q07A04    패스트푸드

# %%
food_df['상호명'].unique()
# 버거 피자 단어가 포함된 상호명 추출
# list1 = ['맥도날드','버거킹','맘스터치','롯데리아','뉴욕버거','써브웨이']
# Out:
# array(['메가박스상봉', '잠원야외수영장', '좀비수제버거', '화이브앤투버거저니', '롯데리아올림픽공원점', '탐앤탐스',
#        '맥도날드양평SKDT점', '맥도날드명지대점', '맥도날드', '빅마켓조리코너', '샌드위치카페', '버거킹',
#        '유로코피자', '밀스버거', '맥도날드구의역점', '생크림와플과뻥아이스', '롯데리아', '자니로켓',
#        'ASAPPIZZA', '케이에프씨방배역', '맥도날드한양대점', '노브랜드', '바스버거', '톰스피자치킨호프',
#        '먼데이브런치', 'TS푸드앤시스템파파이스', '케이에프씨홍익대매장', '죠샌드위치', '부어치킨.피자투어',
#        '롯데리아명일DT점', '북천', '캐슬피씨방', '베터버거중앙대학교점', '토니버거', 'SRSKFC서소문',
#        'SRSKFC일원동점', '아이리시포테이토', '봉구스밥버거쌍문점', '사랑방', '맥도날드어린이대공원점',
#        '롯데마트', '매니피자', '맥도날드서초GS점', 'T.G.I.F롯데영등포점', '봉구스밥버거',
#        '씨제이푸드빌푸드온에어', '롯데리아중화역점', '써브웨이서울', '롯데리아중랑역점', '맘스터치', '맘스터치논현점',
#        '파파이스', '뉴욕버거킹', 'KFC봉천역봉천역', '고로케쿡coffee', '맘스터치망원역점', '뉴욕버거',
#        '크라제', '도미노피자', '버거투버거', '맥도날드강남삼성DT점', '롯데리아강남우성사거리점', '드림스페이스',
#        '카츠로우', '비안', 'The기똥찬수제햄버거&컵밥난향점', '전주식당', '롤랜드버거', '청집',
#        '써브웨이아차산점', '크라제버거', '써브웨이종로점', '버거킹석촌점', '써브웨이구로NC점', '남자피자',
#        '버거주의', '버거헌터', '샐러디', '맥도날드방학역DT점', '노브랜드버거', '롯데리아KKD사업본부',
#        '은솜버거카페', '한국맥도날드서울시흥DT점', '버거1984', '루나리치', '브랜디스트', '반미362',
#        '버거킹연세로점', '뉴욕버거가든파이브점', '테이스티버거', '브루클린더버거조인트', '다운타우너',
#        '버거앤프라이즈', '던킨도너츠', '미국식', '폴트버거', 'KFC', '비스티버거', '이삭토스트', '삐삣버거',
#        '힘난다버거', '길벗버거', '보스버거', '제레미버거', 'UFO버거·코이라멘', '패티앤베지스', '마시써머거바',
#        '맥도날드쌍문DT점', '에릭슨햄버거', '짱스버거', '7번가피자', '롯데리아빌라드샬롯', '햄버거맨',
#        '단골많은꽈배기', '롯데리아남부터미널점', '버거바이트', '일구공', '599버거', '프랭크버거', 'UFO',
#        '피츠버거이태원본점', '햄버거파파', '버거킹청담주성GS점', '맥도날드고척DT점', '버거킹대치역점',
#        '프랭크버거건대', '666버거', '노스트레스버거', '코레일유통부산어묵', '버거앤', '리안스베이글',
#        '소풍가는날', '맥도날드구산점', '맥도날드서울번동DT점', '자마버거', '버거브라더', '맥도날드송정역점',
#        '윙스버거신야텐야EX', '반올림피자샵', '멕스칸햄버거', '쏘자', '맘스터치성균관대점', '스타벅스',
#        '롯데리아길음뉴타운점', '타블도우트', '버거킹선릉역점', '롯데리아동묘역점', '맥도날드중계역점',
#        '그랑플라스와플', '맥도날드연세대점', '버거비', '에그셀런트', '키친스테이지', '맥도날드굽은다리역DT점',
#        '태스토팔라피자', '맥도날드우장산DT점', 'KFC우이동우이동점', '설빙', '아라단미', '서브웨이',
#        'KFC코엑스몰', 'CINEQ신도림점2', '세븐크랩스', '맘스터치홍대점', '롯데리아보문역점',
#        '롯데리아용산전자랜드점', 'CINEQ신도림점1', '롯데리아나뚜루잠실롯', '뉴욕피자로솔도치킨',
#        '맥도날드청담DT점', '붕크', '와플대학천호로데오캠퍼스', '봉구스밥버거중랑역점', '쉐이크포테이토',
#        '애니스토리', '팩토리이엔디', '난타5000', '소나', '보거너앤커터앤벅', '롯데리아자바커피잠실교보',
#        '파이데이3.14', '핑크트럭', '스케치피자치킨', '스모', '빈스앤와플북가좌점', 'BKR버거킹대치점',
#        '써브웨이홍제점', 'ZENNYPIZZA', '서브웨이중랑역점', '스타코넷', '로드샌드위치', '러쉬',
#        '써브웨이응암점', '쉐프밥버거번동점', '모스버거코리아대치역점', '내여자를부탁해', '아이씨지', '아레나',
#        '롯데리아마천점', 'CGV', '써브웨이한성대점', '메이플델리&진격의토스트', '피자스쿨', '롯데리아번동D/T점',
#        '롯데리아군자점', '쉐프밥버거', '버거킹연신내역점', '미소', '바네스', '빙달명일점', '노원토스트',
#        '와플잇업', '써브웨이순화동라마다점', '푸드트럭한끼', 'MOMSTOUCH맘스터치', '롯데리아삼양사거리점',
#        '다농패스트푸드', '달라호스', '모스버거', '유기택피자', '팝콘팩토리', '버거보이성수낙낙점', '퀴즈노스시청',
#        '매크로', '플라잉볼', '롯데리아봉천역점', '크라이치즈버거', '토스', '고릴라수제버거&컵밥', '미스터버거',
#        '오공일파스타', '맥도날드전농점', '바디쉐프지밸리몰점', '플레이보6익스프레스', '양키스버거',
#        '허유산현대백화점', '스매쉬치즈버거', '써브웨이', '홍루이젠', '채one', '못난이꽈배기',
#        '롯데리아송파하비오점', '롯데리아구의점', '봉구스밥버거도봉점', '버거킹거여역점', '더백푸드트럭',
#        'PetitLune', '페이머스하와이쉬림프', '에그드랍', '미드나잇인서울', '와플대학은행사거리캠퍼스',
#        '봉구스밥버거동국대점', '너랑나랑', '잇테이블', '맥도날드염창디티점', '리버타운버거', '버거킹낙성대2점',
#        '홍루이젠시청센터플레이스점', '스마일명품꽈배기', '맘스터치대학동점', '버거킹교대역점', 'BKR버거킹', '카페',
#        '스마일꽈베기', '파르마', '잰아틀리에', '씨지브이용산아이파크몰6층매점', '퀴즈노스', '스마일찹쌀꽈배기',
#        '윈디스', '디저트39', '맘스터치노원로데오점', '수퍼바이츠', '핫독스',
#        '롯데리아롯데마트행당역점롯데마트행당역점', '롯데리아이수역점', '폰버거', '케이에프씨코리아',
#        '엔와이비엔비버거엔베이글', '롯데리아명지대학점', '롯데리아롯데마트중계점롯데마트중계점', '더레드339',
#        '아이씨지치킨앤버거', '모스버거강남서초점', '모리츠플라츠', '맘스터치명지대점', '베러댄와플',
#        '롯데리아나뚜루부문', '맥도날드서울둔촌DT점', '롯데리아롯데마트행당역점', '롯데리아고대하나스퀘어점고대하나스퀘어점',
#        '롯데리아정릉점', '버거킹길동사거리점', '버거운녀석들', 'Pizza&Deli', '카페거실',
#        '홍루이젠종로타워8점', '홀랜드앤바렛', '에그드랍피나클', '버거워', '스타컴즈', '씨지브이압구정',
#        '벌스데이즈샌드위치', '롯데리아송파점', '버거타임', '라라버거', '보다,성수', '버거킹양재점',
#        '아이스크림세상', '컴포즈', '피자헤븐', '선데이버거클럽', '더블유매점', '롯데리아홈플러스영등포점',
#        '롯데리아홈플러스강서점', '스테프핫도그', '버거윈하우스', '지엠피', '조이샌드위치', '버거팜',
#        '아메리칸에그샌드이대서울병원점', '델리', '버거인', '오즈', '불고기파티', '본스토스트',
#        '노브랜드버거메가박스상암', '듀크버거', '밸런스버거', '버거베어', '버거킹충무로역점', '누들톡',
#        '토스티로드', 'OKIS', '롯데리아건대역점', 'EGGDROP서울로테라스점', '티제이브런치앤그릴', '버거락',
#        '감동까스', '브렉퍼스트다이너', '마고닭', '아이엠케익', '봉구스밥버거봉화산역점', '1993버거', '힘난다',
#        '봉구스밥버거외대후문점', '써브웨이봉은사역점', '와플라스', '닭광정앤저스트버거', '샌드리아',
#        '롯데리아홈플러스시흥점', '맥도날드파리공원점', '포포인', 'BBQ치킨', '봉구스밥버거가좌DMC점',
#        '맘스터치중곡역점', '분더버거', '육첩반상', '환공어묵', '써브웨이여의도화재보험점', '스트릿츄러스',
#        '버거킹종로구청점', 'BKR버거킹수서점', '오키스', 'CGV신촌아트레온', '피엠푸드', '특허받은맛집',
#        '피비플러스2호점', 'BKR버거킹쌍문점', '버거킹신당역점', '영사미', '고피자', '버거킹고대중앙광장점',
#        'BKR버거킹시청역점', '베러댄와플중앙대점', '버거킹명일SK점', '에르제Herge', '비프앤치즈',
#        '키친502', 'CGV구로10', '조이직미스터피자', '멀티컬렉션 키스더바리스타', '압구정로데오누들',
#        '스위트몬스터', '바불리옛날왕만두', '디센트', '롯데시네마', '봉구스밥버거전농사거리점', '피자헛', '버거핏',
#        '한국맥도날드가산비즈니스센터점', '한국맥도날드등촌DT점', '써브웨이동대문역사문화공원역점', '59피자',
#        '맘스터치장안점', '버거킹장안SK점', '피자알볼로', '롯데리아영주', '59피자상계7단지점',
#        '서브웨이용산전자랜드점', '더캠프피씨', '한입만푸드트럭', '달콤', '코너하우스바이크루즈더버거',
#        '디마떼오대학로점', '태림산업', '신맥종암SK점', '플라이팬', '케이에프씨강남대로', '와플팝',
#        '펀버거코리아', 'kfc', '미아역KFC점', '미성에프앤씨신재반상', '명랑시대쌀핫도그',
#        '한국맥도날드마리오아울렛', '와플대학', '블랑', '애니피자', '마리스피자', 'CU', '피자굼처',
#        '피치타임', '기가버거중곡점', '롯데리아신방화역점', '한국맥도날드신월SKD', '우리피자', '버거앤쉐이크',
#        '피자로빈', '피자애플', '미스사이공', '에스알에스코리아', '퍼플러브', '아원', '피자마루',
#        '봉구스밥버거궁동점', 'BHC치킨', '티엔', '퀴즈노스서브', '스트릿츄러스광운대점', '맘스터치신대방점',
#        '와플그란데', '병천가마솥손대국', '맘스터치한양대점', '스위트샵', '마리노피자', '뚱스밥버거',
#        'sweetcubeNkitchen', '씨지브이알', '바른밥버거성신여대미아점', '에스씨비에이치',
#        '기똥찬수제햄버거&컵밥', '소딜리셔스카페', '벨라빈스', '롯데리아강동구청D/T', '맥도날드쌍문DT',
#        '샌드위치몽', '장호덕손만두도곡점', '현진이네', '에스알에스KFC월계이마트', '이태리하우스', '빵이가',
#        '버거파크', '고리', '현대빌딩롯데리아', '밀크밥버거', '맥도날드중랑점', '피자나라치킨공주', '안젤로',
#        '소운빙', '루샌드위치', '맘스터치신촌점', '자미당', '와플몬스터', '에이치번즈', '비에뜨반미현대',
#        '버거킹신림역점', '맥도날드종로3가점', '소풍', '봉구스밥버거아현점', '와플하우스', 'GS25',
#        '파파밸리피자', '카퍼룸라마다서울호텔', '청춘감성쌀핫도그', '타코벨이태원점', '뚱스크라운밥버거', '다락방',
#        '배스킨라빈스교대점', '맥도날드과학기술대점', '마미쿡치킨앤버거', '롯데리아미아삼거리점', '버거킹구로구청점',
#        '씨지브이신촌아트레온매점2', '아이엠버거', '맥도날드위례신도시점', '반트와플목동점', '달그락', '맘쓰밥버거',
#        '한국맥도날드강남삼성DT점', '버거빌', '대니버거', '스카이식당', '빔벅스', '디핀다트코리아',
#        '써브웨이선릉점', '퀴즈노스문정', '라멜라', '맥도날드성균관대점', '루니리치반포래미안점', 'BKR버거킹문정점',
#        'BKR버거킹쌍문SK점', '뚜비뚜밥스', '왕산골왕만두', '맥도날드서울동묘역점', '금복당',
#        '씨제이푸드빌김포푸드오클락', '플라잉볼익스프레스', '롯데리아시흥중앙점', '도미노피자홍제점', '롯데리아길동점',
#        '파이어벨', '웰빙쌀빵', '버거킹가재울뉴타운점', '이삭토스트화양점', '롤링핀', '셰프리',
#        '모스버거명동중앙점', '썬하우스', '롯데마트구내식당VIC마켓영등포점', '맘스터치종로대학로점',
#        'BKR버거킹송파구청점', 'BKR버거킹목동이마트점', '롯데리아고덕역점', '맥도날드장안사거리점', '와플스타',
#        'CGV대학로', '그랑프리피자', '그리드잇', '하이도죠', '한국맥도날드강남2호', '한국맥도날드은평이마트',
#        '옐로우버거', '에팡', '피자세계로', '맥도날드이수점', '맥도날드숭실대점', '맥도날드서울상암DMC점',
#        '맥도날드가산디지털점가산디지털점', '양평sk맥도날드', '롯데리아노원역점', '글로벌피자', '도이첸', '뉴스보이',
#        '에스알에스KFC압구정1', '몽키피자', '롯데리아T.G.I.F잠', '스타시티건대', '걸리버피자',
#        '맥도날드석촌역점', '서휘동피자치킨', '수피자', '끼리끼리', '씨지브이대학로1', 'CAFE,와플대학',
#        '와플루이', '맥도날드삼선점', '롯데리아ANGELIN', 'SKfC', '디나폴리', '멜팅그릴', '피치홈',
#        '맥도날드신사역점', '영철스트리트버거', '롯데리아장안사거리점', '서브웨이한국지사한국지사', '북촌손만두',
#        '이태리피자', '석봉토스트', '킴스버거앤샌드', '피자센스돈암직영점', '와플스', '봉구스', '델라마노',
#        '라이스&포테이토', '와플몽', '바스버거마곡', '포테이토', '맥도날드서초뱅뱅점', '피자스쿨면목점',
#        '유니스얼반키친', '파파존스피자미아점', '모스버거코리아', '길버트버거앤프라이즈', '쥴리앙와플', '오늘또피자',
#        '맥도날드중계점', '케익커리퐁당', '후PC방', '버거스버거스', '88시장버거', '아이센스리그PC방',
#        '엉클톰', '베스킨라빈스이마트점', '버거준', 'ANNISE', '가미크래프트갤러리', '정글버거',
#        'Reddevil', '프레쉬버거', '본푸드시스템', '빵사이에낀과일', '피자815', '에스케이에프씨',
#        '로칼스', '더클럽객석2층', '대포햇도그', '핫도그찹찹', '부빙', '브로스버거', '뎅댕깔조네버거',
#        '한국맥도날드상계DT점상계DT점', '한국로날드맥도날드하우스', '롯데리아TGIF사업부', '한국맥도날드신도림디큐브',
#        '봉구스신대방점', 'BKR버거킹압구정로데오점', '한끼컵밥', '모노치즈', 'BKR버거킹건대역점', '당돌',
#        '쉐이크쉑', '홍플러스더피자', '32파르페', '리얼후라이', '엘본인터내셔날', '미스터피자', '마일스톤',
#        '올드캡', '네오피자', '베리스타', '이스포츠PC방', 'SUBWAY', 'Shakeshake',
#        '더오리지날팬케', '에그스탑', '창대에프씨길버거광운대점', '버거랩', '버거쿡', '피자연합', '해피데이',
#        '국민카페1관', '로날드맥도날드하우스', '유썸퀴즈노스역삼점', '죠스샌드위치', '버거킹연희점', '주성에프엔디',
#        '까르보네', '한국맥도날드미아DT점', '롯데리아구로가산점', '더피자보이즈', '맘스터치신월점', '그롬',
#        '로사키친리틀아시아', '써브웨이성신여대점', '망고', '미가', '크라제맥스한양엠케이점', '나띵베러',
#        '롯데리아혜화점', '타코야King', '제퍼강남', '메이플유통', '롯데리아구로시장점', 'wecrepe',
#        '쓰리팝PCCAFE', '영철버거', '파머스박스수서역사점', '버거킹목동역점', '버거킹청담점', '롯데리아신천점',
#        '투게더', '뉴욕아파트먼트오리지날그릴', '지엠에스글로벌', '미스터파파임실치즈피자', '씨제이씨지브이',
#        '뚱스밥벅니', '아워홈국민대', '길버트버거앤프라이즈이태원', '참살이임실치즈피자', '참사랑마을', '비킷버거',
#        '버거점프', '책갈피', '아메리칸델리', '바겟버거', '번패티번', '유에프오', '블리스버거',
#        '씨지브이아이앤씨', '포온스', '피자아이', '목동버거', '칙피스', '엘더버거', 'GDBURGER&PUB',
#        '탄자니아', '에그오리진', '정쓰샌드위치', '고털푸드', '롯데리아시흥', '버거4.5', '올바른버거',
#        '엔스버거', '수통이버거익스프레스', '좋앗나', '도니버거', '카페메종드한', '노브랜드버거잠실학원사거리점',
#        '롯데리아합정점', '롯데리아사당점', '피터스버거', '버거퀸햄버거', '신일상사', '맥도날드신천점', '버거뱅',
#        '버거킹사당역점', '오스버거', '회기버거', '아마스빈', '토성', '케이에프씨석촌역', '릿잇타미',
#        '월계이마트KFC', '버거100', '빈스버거', '키아네', '솔아띠몽', '구뜨', '블랙페퍼574',
#        '브레덴버거', '유에프오버거', 'CEO의탄생', '더샌드위치샵', '서울트럭', '델리스타', '코넷데프리츠',
#        '꿀닭', '에스알에스케이에프씨', '써브웨이연희점', '러브레터', '롬바르디아', '구버먼트햄버거아머리',
#        '써라운드버거', '이태원더버거익스프레스', '뉴욕비앤비', '카파노', '루이스버거', '고니스', '티탄버거',
#        '오구본가오류', '신디셀리수제버거', '더브', '더봄길', '디슨트하우스', '더브니크', '블란서크로플',
#        '텍사스버거앤베이글', '슬로피버거', '푸드죤', '펜지뉴욕버거고덕', '코레일유통어묵일품', '황제꽈배기',
#        '블루픽', '압구정샌드위치by카터알망', '치클스', '프랭크수제치즈버거', '오로라버거앤샐러드', '데어리퀸',
#        'UFO버거', '자작카페핸리', '회기버거경희궁', '압구정샌드위치', '해브어그린',
#        '바겟버거고려대현대자동차경영관점', '프랑크버거', '선명희피자', '이목구비', '파파존스', '니꾸킹버거',
#        '제이룸은버거입니다', '에그몬', 'BGT호두단팥빵', '한울타리', '비츠버거', '바이트', '투데이',
#        '원피스샌드위치', '명작호두과자', '빌리언박스', '벅벅', '롯데컬처웍스롯데시네마신도림', '제이엠티엔드버거',
#        '파파에그토스트', '스윅', '딜리버거', '아마당', '롯데월드김피라스넥', '하프앤', '명칭없음',
#        '타코몽타코야끼', '씨아이푸드', '범피버거', '코너샵', '윙스버거', '테임디쉬', '밀리언버거', '디씨티',
#        '훈연호버거', '아이엠어버거', '버거베어역삼아크플레이스', '깡쓰버거', '버거앤프라이즈Burger&Friez',
#        '더피플버거', '6번지버거', '버거앤프라이즈서울', '버터버거', '컴튼', '버거파이터', '너의작은버거집',
#        '버거리', '황다방', '리미티드버거', '서울대500동나인온스버거', '성수망치버거', '딜리버거&샐러드',
#        '버거앤프라이즈신길', '수제버거rgb', '티제이버거앤파스타헬리오', '타이거버거빅마켓', '파운드버거',
#        '예삐버거', '해피버거데이', '웨스트버거', '프랭크버거마곡나루역점', '조이버거', '크로플바베큐버거',
#        '위스키와햄버거', '노브랜드버거신논현역점2', '프랭크버거목동역7단지점', '이지버거', '에프터드링크버거',
#        '서양가트니', '포미키친', '쉐프마스터', '부쳐', '삼촌네햄버거', '스미뜨', '알리바바버거', '버거호',
#        '퍼스버거', '위드번', '버거더와이즈', '레드앤그린버거', '코코살사', '땡스버거', '버거스올마이티',
#        '노머시버거', '버거샵', '프랭크버거왕십리텐즈힐점', '버거버거', '버거룸', '서오릉피자'],
#       dtype=object)

# %%
 food_df = food_df[food_df['상호명'].str.contains("버거|피자")].copy()

# %%
food_df = food_df[['상호명','시군구명','행정동명','도로명주소','위도','경도']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 559 entries, 722 to 323930
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   상호명     559 non-null    object
#  1   시군구명    559 non-null    object
#  2   행정동명    559 non-null    object
#  3   도로명주소   559 non-null    object
#  4   위도      559 non-null    float64
#  5   경도      559 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 30.6+ KB

# %%
food_df = food_df.reset_index(drop=True)
food_df
# Out:
#            상호명  시군구명   행정동명                   도로명주소         위도          경도
# 0       좀비수제버거   마포구    염리동       서울특별시 마포구 숭문길 210  37.555761  126.946630
# 1    화이브앤투버거저니   강남구   논현2동    서울특별시 강남구 언주로115길 18  37.509951  127.035149
# 2          버거킹   강동구   성내2동     서울특별시 강동구 천호대로 1012  37.538090  127.124133
# 3        유로코피자  동대문구   휘경2동    서울특별시 동대문구 망우로20길 59  37.590658  127.065440
# 4         밀스버거   용산구   한강로동    서울특별시 용산구 한강대로 210-2  37.537128  126.974421
# ..         ...   ...    ...                     ...        ...         ...
# 554       버거버거   동작구  신대방2동  서울특별시 동작구 여의대방로22길 121  37.498256  126.926629
# 555        버거룸   송파구   송파2동       서울특별시 송파구 가락로 156  37.502983  127.113018
# 556      프랭크버거   강남구   대치4동     서울특별시 강남구 선릉로86길 15  37.503518  127.050817
# 557     노브랜드버거   광진구   중곡1동      서울특별시 광진구 천호대로 549  37.557794  127.078855
# 558      서오릉피자   노원구  상계10동     서울특별시 노원구 노원로38길 76  37.663996  127.062277
#
# [559 rows x 6 columns]

# %%
# 새로운 컬럼 생성 하고 기본값으로 버거를 셋팅
# 상호명에 피자가 들어가 있는 index

# %%
food_df['종류'] = '버거'

# %%
piza_index = food_df[food_df['상호명'].str.contains("피자")].index

# %%
food_df.loc[piza_index,'종류'] = '피자'

# %%
food_df
# Out:
#            상호명  시군구명   행정동명                   도로명주소         위도          경도  종류
# 0       좀비수제버거   마포구    염리동       서울특별시 마포구 숭문길 210  37.555761  126.946630  버거
# 1    화이브앤투버거저니   강남구   논현2동    서울특별시 강남구 언주로115길 18  37.509951  127.035149  버거
# 2          버거킹   강동구   성내2동     서울특별시 강동구 천호대로 1012  37.538090  127.124133  버거
# 3        유로코피자  동대문구   휘경2동    서울특별시 동대문구 망우로20길 59  37.590658  127.065440  피자
# 4         밀스버거   용산구   한강로동    서울특별시 용산구 한강대로 210-2  37.537128  126.974421  버거
# ..         ...   ...    ...                     ...        ...         ...  ..
# 554       버거버거   동작구  신대방2동  서울특별시 동작구 여의대방로22길 121  37.498256  126.926629  버거
# 555        버거룸   송파구   송파2동       서울특별시 송파구 가락로 156  37.502983  127.113018  버거
# 556      프랭크버거   강남구   대치4동     서울특별시 강남구 선릉로86길 15  37.503518  127.050817  버거
# 557     노브랜드버거   광진구   중곡1동      서울특별시 광진구 천호대로 549  37.557794  127.078855  버거
# 558      서오릉피자   노원구  상계10동     서울특별시 노원구 노원로38길 76  37.663996  127.062277  피자
#
# [559 rows x 7 columns]

# %%
# 서울에 있는 소상공인 데이터중에 중분류 소분류가 패스트푸드이고 업종에 피자 나 버거가 들어가 있는 상점들

# %%
sns.countplot(data=food_df,y='종류')
plt.title('서울시')
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(data=food_df,y='종류',hue='시군구명')

# %%
# 상권중에서 시군구별로 시각화
temp = food_df.groupby(['시군구명','종류'])['상호명'].count()
temp = temp.reset_index()
temp
sns.catplot(data=temp, y='종류',x='상호명',col='시군구명',col_wrap=4,kind='bar')

# %%
food_df
sns.scatterplot(data=food_df,x='경도',y='위도',hue='종류')
# Out:
# <AxesSubplot:xlabel='경도', ylabel='위도'>

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\user\miniconda3\envs\ml\lib\site-packages (0.12.1.post1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\user\miniconda3\envs\ml\lib\site-packages (from folium) (1.23.1)
# Requirement already satisfied: requests in c:\users\user\miniconda3\envs\ml\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\user\miniconda3\envs\ml\lib\site-packages (from folium) (0.5.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\user\miniconda3\envs\ml\lib\site-packages (from folium) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\miniconda3\envs\ml\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\miniconda3\envs\ml\lib\site-packages (from requests->folium) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\miniconda3\envs\ml\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\miniconda3\envs\ml\lib\site-packages (from requests->folium) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\miniconda3\envs\ml\lib\site-packages (from requests->folium) (3.3)

# %%
import folium

# %%
lat =  food_df['위도'].mean()
lnt = food_df['경도'].mean()

# %%
m = folium.Map([lat,lnt])

# %%
for i in range(len(food_df)):
    temp = food_df.loc[i]
    folium.Marker(
        [temp['위도'],temp['경도']],
        tooltip=temp['상호명'] + '-' + temp['도로명주소']
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fdf7f3acfd9b61362767a17af67bd26d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fdf7f3acfd9b61362767a17af67bd26d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fdf7f3acfd9b61362767a17af67bd26d = L.map(
#                 &quot;map_fdf7f3acfd9b61362767a17af67bd26d&quot;,
#                 {
#                     center: [37.54811449674905, 126.99490160553417],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5c49e05a403bd5eaca4890f3361d117 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fdf7f3acfd9b61362767a17af67bd26d);
#
#
#             var marker_1f8f2c429f18bff8ee2d022ba625fd7e = L.marker(
#                 [37.5557605517735, 126.946629505003],
#                 {}
#             ).addTo(map_fdf7f3acfd9b61362767a17af67bd26d);
#
#
#             marker_1f8f2c429f18bff8ee2d022ba625fd7e.bindTooltip(
#                 `&lt;div&gt;
#                      좀비수제버거-서울특별시 마포구 숭문길 210
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2d8ba6abd44e25b4556b929506120799 = L.marker(
#                 [37.5099508361588, 127.035149118088],
#                 {}
#             ).addTo(map_fdf7f3acfd9b61362767a17af67bd26d);
#
#
#             marker_2d8ba6abd44e25b4556b929506120799.bindTooltip(
#                 `&lt;div&gt;
#                      화이브앤투버거저니-서울특별시 강남구 언주로115길 18
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2044657af5209f8b023be861c7778f47 = L.marker(
#                 [37.5380903953149, 127.124132813668],
#                 {}
#             ).addTo(map_fdf7f3acfd9b61362767a17af67bd26d);
#
#
#             marker_2044657af5209f8b023be861c7778f47.bindTooltip(
#                 `&lt;div&gt;
#                      버거킹-서울특별시 강동구 천호대로 1012
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ffe2d68d15ffc8c789e614f1a62686a6 = L.marker(
#                 [37.5906581399497, 127.065439737758],
#                 {}
#             ).addTo(map_fdf7f3acfd9b61362767a17af67bd26d);
#
#
#             marker_ffe2d68d15ffc8c789e614f1a62686a6.bindTooltip(
#                 `&lt;div&gt;
#                      유로코피자-서울특별시 동대문구 망우로20길 59
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b0c9062f31cefb7c899d0cc686b11181 = L.marker(
#                 [37.537128360432, 126.974421351957],
#                 {}
#             ).addTo(map_fdf7f3acfd9b61362767a17af67bd26d);
#
#
#             marker_b0c9062f31cefb7c899d0cc686b11181.bindTooltip(
#                 `&lt;div&gt;
#                      밀스버거-서울특별시 용산구 한강대로 210-2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bb1c8186778934a0be3a865229e83e74 = L.marker(
#                 [37.6099054005981, 127.078167489117],
#                 {}
#             ).addTo(map_fdf7f3acfd9b61362767a17af67bd26d);
#
#
#             marker_bb1c8186778934a0be3a865229e83e74.bindTooltip(
#                 `&lt;div&gt;
#                      버거킹-서울특별시 중랑구 동일로 890
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_34e6e125827169888f5622df43408d5f = L.marker(
#                 [37.4835612005581, 126.895484835804],
#                 {}
#             ).addTo(map_fdf7f3acfd9b61362767a17af67bd26d);
#
#
#             marker_34e6e125827169888f5622df43408d5f.bindTooltip(
#                 `&lt;div&gt;
#                      버거킹-서울특별시 구로구 디지털로 288
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_78ac680b56dee92159ac453063940352 = L.marker(
#                 [37.4845512962666, 127.120744114354],
#                 {}
#             ).addTo(map_fdf7f3acfd9b61362767a17af67bd26d);
#
#
#             marker_78ac680b56dee92159ac453063940352.bindTooltip(
#                 `&lt;div&gt;
#                      바스버거-서울특별시 송파구 송파대로 167
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1aad4383795368f2dbfbf3023a9d9c5e = L.marker(
#                 [37.6051772998091, 126.965401424089],
#                 {}
#             ).addTo(map_fdf7f3acfd9b61362767a17af67bd26d);
#
#
#             marker_1aad4383795368f2dbfbf3023a9d9c5e.bindTooltip(
#                 `&lt;div&gt;
#                      톰스피자치킨호프-서울특별시 종로구 평창문화로 37
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f433e3264513baa1b0e55ae72e486a4c = L.marker(
